# %% [markdown]
# # Matplotlib Basic

# %%
# Step 1: See the input data first in our coffee_sales.csv

# Step 2: Import our libraries and load in the data
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

BASE_DIR = Path.cwd()
DATA_DIR = BASE_DIR / "data"

df = pd.read_csv(DATA_DIR / "coffee_sales.csv")
